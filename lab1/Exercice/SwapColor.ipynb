# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = '../gamora_nebula.jpg'
im = cv2.imread(filename)

# %%
#redimensiona a imagem
new_width = int(im.shape[1] * .5)
new_height = int(im.shape[0] * .5)
dim = (new_width, new_height)
im_resized = cv2.resize(im, dim, interpolation = cv2.INTER_AREA)

plt.imshow(im_resized)

# %%
def calculate_threshold_value(color):
        # Converter a cor do picker para o espaço de cores HSV
        color_hsv = cv2.cvtColor(np.uint8([[color]]), cv2.COLOR_RGB2HSV)[0][0]
        # Obter o componente de valor (V) da cor HSV
        v_value = color_hsv[2] #hue #saturation #value
        # Definir um fator para ajustar o valor de thresholding
        threshold_factor = 0.8  # Ajuste conforme necessário
        # Calcular o valor de threshold com base no componente de valor (V)
        threshold_value = v_value * threshold_factor
        return threshold_value
        
        # #Calcular a média dos valores R, G e B
        # avg_color = np.mean(color)
        # # Definir um fator para ajustar o valor de thresholding
        # threshold_factor = 0.8  # Ajuste conforme necessário
        # # Calcular o valor de threshold com base na média dos valores R, G e B
        # threshold_value = avg_color * threshold_factor
        # return threshold_value

# %%
def draw_imgs(imgs):
    size = len(imgs)
    for i in range(size):
        plt.subplot(1,size,i+1),plt.imshow(imgs[i])
    plt.show()

# %% [markdown]
# ## Usando Threashold

# %%
im_hsv = cv2.cvtColor(im_resized, cv2.COLOR_BGR2HSV)
im_final = cv2.cvtColor(im_hsv, cv2.COLOR_HSV2RGB)
im_bk = im_final.copy()
r,g,b = cv2.split(im_hsv)

x1, y1 = 200, 100
x2,y2 = 500, 100

img_base = r

color1_hsv = img_base[y1,x1]
color2_hsv = img_base[y2,x2]


########################

value1 = 185#calculate_threshold_value(color1_hsv)
value2 = 60#calculate_threshold_value(color2_hsv)
print(value1, value2)
ret, mask1 = cv2.threshold(g,value1,255,cv2.THRESH_BINARY)
# mask1 = mask_invertida = cv2.bitwise_not(mask1)
ret, mask2 = cv2.threshold(r,value2,255,cv2.THRESH_BINARY)
mask2 = mask_invertida = cv2.bitwise_not(mask2)
########################

color1 = im_bk[y1,x1]
color2 = im_bk[y2,x2]

im_final[mask1 > 0] = color2
im_final[mask2 > 0] = color1

draw_imgs([im_bk, mask1, mask2])
draw_imgs([im_hsv, r, g, b])
draw_imgs([im_final])
# Out:
# 185 60

# %% [markdown]
# ## Usando Intervalo

# %%
im_hsv = cv2.cvtColor(im_resized, cv2.COLOR_BGR2HSV)
im_final = cv2.cvtColor(im_hsv, cv2.COLOR_HSV2RGB)
im_bk = im_final.copy()
r,g,b = cv2.split(im_hsv)

x1, y1 = 45, 250
x2, y2 = 500, 250

img_base = r

color1_bot = img_base[y1, x1]
color2_bot = img_base[y2, x2]

x1, y1 = 190, 200
x2, y2 = 510, 325

color1_top = img_base[y1, x1]
color2_top = img_base[y2, x2]
########################

mask1 = cv2.inRange(img_base, np.array(color1_bot), np.array(color1_top))
mask2 = cv2.inRange(img_base, np.array(color2_bot), np.array(color2_top))

########################


x1, y1 = 200, 100
x2,y2 = 500, 100
color1 = im_bk[y1,x1]
color2 = im_bk[y2,x2]

im_final[mask1 > 0] = color2
im_final[mask2 > 0] = color1

draw_imgs([im_bk, mask1, mask2])
draw_imgs([im_hsv, r, g, b])
draw_imgs([im_final])
