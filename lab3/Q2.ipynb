# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('./Fiddlesticks.jpg')

if img is None:
    print("Erro ao carregar a imagem.")
    exit()

# Converter para escala de cinza
R, G, B = cv2.split(img)
Y = (0.3 * R) + (0.59 * G) + (0.11 * B)
print(Y)
# Converter o resultado para 8 bits, se necessário
if img.dtype != np.uint8:
    Y = cv2.convertScaleAbs(Y)

# Converter de volta BGR
gray_img = cv2.cvtColor(Y.astype(np.uint8), cv2.COLOR_GRAY2BGR)

# Exibir as imagens lado a lado
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
ax[0].set_title('Imagem Original')

ax[1].imshow(cv2.cvtColor(gray_img, cv2.COLOR_BGR2RGB))
ax[1].set_title('Imagem em Tons de Cinza')

plt.show()
# Out:
# [[108.16 105.16 105.17 ...  41.36  44.73  44.96]
#  [106.16 103.16 103.17 ...  32.36  34.73  35.36]
#  [106.17 104.17 104.77 ...  32.65  33.65  34.65]
#  ...
#  [ 55.18  50.18  49.58 ...  82.9   83.9   84.9 ]
#  [ 55.18  50.18  51.06 ...  84.9   85.9   85.9 ]
#  [ 57.81  53.18  53.06 ...  84.9   85.9   85.9 ]]
